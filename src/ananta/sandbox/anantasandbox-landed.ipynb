# %%
import os
import sys
from sys import platform

from ananta.Common import CustomLogger, Messages
from ananta.core import Ananta
from pyspark.sql import functions as F

if os.environ.get("LOCAL_DEV", False):
    if platform == "linux" or platform == "linux2":
        # linux
        pass
    elif platform == "darwin":
        sys.path.insert(0, "/Users/kom/code/ananta/ananta/src")

    elif platform == "win32":
        sys.path.insert(0, "C:/Users/PtPashantTripathi/code/ananta/src")


def print_var(value):
    print(f"---------\n{value}\n-----------")


DATA_SOURCE = "ESS"
OBJECT_NAME = "rptOOS"
COUNTRY = "VN"
LAYER = "BRONZE"
STAGE = "Landed"
NAME = f"{COUNTRY} Data beecost"
DESCRIPTION = "test description lorem ipsum"
# DATA_OWNER = "email@example.com"
# PROCESS_OWNER = "email1@example.com"
IS_ENABLED = True
CRON = "0 8 * * */1"
FILE_PATH = (
    "C:/Soft/test_20221001.csv"
    if platform == "win32"
    else "./rptOOS_20220921.parquet,./rptOOS_20220921_2.parquet"
)
SAVE_MODE = "overwrite"
DEBUG = False
OBJECT_TYPE = "parquet"
LANDING_DATE = "2022-10-10"
DATA_CATALOG = False

app = Ananta(
    country=COUNTRY,
    layer=LAYER,
    stage=STAGE,
    data_source=DATA_SOURCE,
    object_name=OBJECT_NAME,
    file_path=FILE_PATH,
    save_mode=SAVE_MODE,
    object_type=OBJECT_TYPE,
    debug=DEBUG,
    landing_date=LANDING_DATE,
    data_catalog=DATA_CATALOG,
)
# def custom_function(variable):
#     return F.udf()
# app.add_custom_udf("colA", "custom_function", "POST_EXTRACT", None)
# app.add_custom_udf("colB", "custom_function2", "PRE_TRANSFORM", None)
# app.add_custom_udf("colC", "custom_function3", "POST_LOAD", None)
app.run()
# app.custom_udf(function_name, "extract/transform/load")  # pre/post
# print_var(app.processor.dict())
print(app.get_runtime_report())
# Out:
# darwin
# path added
# Deequ is still not supported in spark version: 3.2.1
# 23/03/09 09:39:01 WARN Utils: Your hostname, Quans-MacBook-Pro.local resolves to a loopback address: 127.0.0.1; using 192.168.1.209 instead (on interface en0)
# 23/03/09 09:39:01 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# :: loading settings :: url = jar:file:/Users/kom/code/spark-3.2.1-bin-hadoop3.2/jars/ivy-2.5.0.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /Users/kom/.ivy2/cache
# The jars for the packages stored in: /Users/kom/.ivy2/jars
# io.delta#delta-core_2.12 added as a dependency
# com.amazon.deequ#deequ added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-d61e3a68-6a17-4fea-b4b4-426866ff14b3;1.0
# 	confs: [default]
# 	found io.delta#delta-core_2.12;2.0.1 in central
# 	found io.delta#delta-storage;2.0.1 in central
# 	found org.antlr#antlr4-runtime;4.8 in central
# 	found org.codehaus.jackson#jackson-core-asl;1.9.13 in central
# 	found com.amazon.deequ#deequ;2.0.1-spark-3.2 in central
# 	found org.scala-lang#scala-reflect;2.12.10 in central
# 	found org.scalanlp#breeze_2.12;0.13.2 in central
# 	found org.scalanlp#breeze-macros_2.12;0.13.2 in central
# 	found com.github.fommil.netlib#core;1.1.2 in central
# 	found net.sf.opencsv#opencsv;2.3 in central
# 	found com.github.rwl#jtransforms;2.4.0 in central
# 	found junit#junit;4.8.2 in central
# 	found org.apache.commons#commons-math3;3.2 in central
# 	found org.spire-math#spire_2.12;0.13.0 in central
# 	found org.spire-math#spire-macros_2.12;0.13.0 in central
# 	found org.typelevel#machinist_2.12;0.6.1 in central
# 	found com.chuusai#shapeless_2.12;2.3.2 in central
# 	found org.typelevel#macro-compat_2.12;1.1.1 in central
# 	found org.slf4j#slf4j-api;1.7.5 in central
# :: resolution report :: resolve 792ms :: artifacts dl 24ms
# 	:: modules in use:
# 	com.amazon.deequ#deequ;2.0.1-spark-3.2 from central in [default]
# 	com.chuusai#shapeless_2.12;2.3.2 from central in [default]
# 	com.github.fommil.netlib#core;1.1.2 from central in [default]
# 	com.github.rwl#jtransforms;2.4.0 from central in [default]
# 	io.delta#delta-core_2.12;2.0.1 from central in [default]
# 	io.delta#delta-storage;2.0.1 from central in [default]
# 	junit#junit;4.8.2 from central in [default]
# 	net.sf.opencsv#opencsv;2.3 from central in [default]
# 	org.antlr#antlr4-runtime;4.8 from central in [default]
# 	org.apache.commons#commons-math3;3.2 from central in [default]
# 	org.codehaus.jackson#jackson-core-asl;1.9.13 from central in [default]
# 	org.scala-lang#scala-reflect;2.12.10 from central in [default]
# 	org.scalanlp#breeze-macros_2.12;0.13.2 from central in [default]
# 	org.scalanlp#breeze_2.12;0.13.2 from central in [default]
# 	org.slf4j#slf4j-api;1.7.5 from central in [default]
# 	org.spire-math#spire-macros_2.12;0.13.0 from central in [default]
# 	org.spire-math#spire_2.12;0.13.0 from central in [default]
# 	org.typelevel#machinist_2.12;0.6.1 from central in [default]
# 	org.typelevel#macro-compat_2.12;1.1.1 from central in [default]
# 	:: evicted modules:
# 	org.scala-lang#scala-reflect;2.12.1 by [org.scala-lang#scala-reflect;2.12.10] in [default]
# 	org.scala-lang#scala-reflect;2.12.0 by [org.scala-lang#scala-reflect;2.12.10] in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   21  |   0   |   0   |   2   ||   19  |   0   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-d61e3a68-6a17-4fea-b4b4-426866ff14b3
# 	confs: [default]
# 	0 artifacts copied, 19 already retrieved (0kB/29ms)
# 23/03/09 09:39:03 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 23/03/09 09:39:09 WARN ANANTA: Initialized Ananta
# 23/03/09 09:39:09 WARN ANANTA: CONTRACT: BROKER: Looking at /Users/kom/code/ananta/ananta/src/ananta/sandbox/data/DataContract/Bronze/Landed/VN/ESS_rptOOS.json - Found True
# 23/03/09 09:39:09 WARN ANANTA: ASSIGNED: BronzeLandedProcessor
# 23/03/09 09:39:09 WARN ANANTA: CORE: Found 0 custom udf
# --Initialized Ananta
# --CONTRACT: BROKER: Looking at /Users/kom/code/ananta/ananta/src/ananta/sandbox/data/DataContract/Bronze/Landed/VN/ESS_rptOOS.json - Found True
# --ASSIGNED: BronzeLandedProcessor
# --CORE: Found 0 custom udf
# ['./rptOOS_20220921.parquet', './rptOOS_20220921_2.parquet']
# 23/03/09 09:39:17 WARN ANANTA: LANDED RAW COMPLETED: 3178
# --LANDED RAW COMPLETED: 3178
# 23/03/09 09:39:18 WARN ANANTA: LANDED TRANSFORM COMPLETED: 3178
# --LANDED TRANSFORM COMPLETED: 3178
# 23/03/09 09:39:20 WARN ANANTA: LANDED LOAD COMPLETED: 3178
# --LANDED LOAD COMPLETED: 3178
# /Users/kom/miniconda3/envs/home-adb/lib/python3.8/site-packages/pyspark/sql/pandas/conversion.py:471: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   arrow_data = [[(c, t) for (_, c), t in zip(pdf_slice.iteritems(), arrow_types)]
# [Stage 29:==========================================>             (38 + 8) / 50]
# --DATA DataQuality: QUALITY: Generate 3178 - 3178 - 3178 columns
# --DATA QUALITY: QUALITY: Complete
# {'raw': 3178, 'transform': 3178, 'load': 3178}
# 23/03/09 09:39:30 WARN ANANTA: DATA DataQuality: QUALITY: Generate 3178 - 3178 - 3178 columns
# 23/03/09 09:39:30 WARN ANANTA: DATA QUALITY: QUALITY: Complete

# %%
if os.environ.get("LOCAL_DEV", False):
    if platform == "linux" or platform == "linux2":
        # linux
        pass
    elif platform == "darwin":
        print(f"path added")
        sys.path.insert(0, "/Users/kom/code/ananta/ananta/src")

    elif platform == "win32":
        sys.path.insert(0, "C:/Users/PtPashantTripathi/code/ananta/src")


def print_var(value):
    print(f"---------\n{value}\n-----------")


DATA_SOURCE = "ESS"
OBJECT_NAME = "rptOOS"
COUNTRY = "VN"
LAYER = "BRONZE"
STAGE = "Processed"
NAME = f"{COUNTRY} Data beecost"
DESCRIPTION = "test description lorem ipsum"
# DATA_OWNER = "email@example.com"
# PROCESS_OWNER = "email1@example.com"
IS_ENABLED = True
CRON = "0 8 * * */1"
# FILE_PATH = "./build/result/Beecost/shopee_category_test/VN/Landed/YYYY=2022/MM=10/DD=10/shopee_category_test_20221010.parquet"
FILE_PATH = None
SAVE_MODE = "overwrite"
DEBUG = True
OBJECT_TYPE = "delta"
LANDING_DATE = "2020-10-10"
PARTITION_BY = "segment,average_rating"

# app = Ananta(
#     country=COUNTRY,
#     layer=LAYER,
#     stage=STAGE,
#     data_source=DATA_SOURCE,
#     object_name=OBJECT_NAME,
#     file_path=FILE_PATH,
#     save_mode=SAVE_MODE,
#     object_type=OBJECT_TYPE,
#     debug=DEBUG,
#     landing_date=LANDING_DATE,
# )
app = Ananta(
    country=COUNTRY,
    layer=LAYER,
    stage=STAGE,
    data_source=DATA_SOURCE,
    object_name=OBJECT_NAME,
    file_path=FILE_PATH,
    save_mode=SAVE_MODE,
    object_type=OBJECT_TYPE,
    debug=DEBUG,
    landing_date=LANDING_DATE,
)


# def custom_function():
#     return F.concat(
#         "seller_id",
#         F.lit("_"),
#         "product_id",
#         F.lit("_"),
#         "model_id",
#         F.lit("_"),
#         F.date_format(F.col("datetime"), "yyyyMMdd"),
#     )


# app.add_custom_udf("uid", custom_function, "POST_EXTRACT", None)
# app.add_custom_udf("colB", "custom_function2", "PRE_TRANSFORM", None)
# app.add_custom_udf("colC", "custom_function3", "POST_LOAD", None)
app.run()
# app.custom_udf(function_name, "extract/transform/load")  # pre/post
# print_var(app.processor.dict())
print(f"-----Result {app.input_df.count()}")  # type: ignore
print(f"----transform: {app.transform_df}")
# Out:
# path added
# --Initialized Ananta
# --DEBUG: NO file_path : looking new /Users/kom/code/ananta/ananta/src/ananta/sandbox/build/result/Bronze/ESS/rptOOS/VN/Landed/YYYY=2020/MM=10/DD=10/rptOOS_20201010.delta/YYYY=2020/MM=10/DD=10/rptOOS_20201010.parquet
# --/Users/kom/code/ananta/ananta/src/ananta/sandbox/data/DataContract/Bronze/Processed/VN/ESS_rptOOS.json
# --CONTRACT: BROKER: Looking at /Users/kom/code/ananta/ananta/src/ananta/sandbox/data/DataContract/Bronze/Processed/VN/ESS_rptOOS.json - Found True
# --ASSIGNED: BronzeProcessedProcessor
# --{'path': {'datalake_path': '/Users/kom/code/ananta/ananta/src/ananta/sandbox/build/result', 'object_path': '/Bronze/ESS/rptOOS/VN/Processed', 'datetime_path': '/YYYY=2020/MM=10/DD=10', 'full_path': '/Users/kom/code/ananta/ananta/src/ananta/sandbox/build/result/Bronze/ESS/rptOOS/VN/Processed/YYYY=2020/MM=10/DD=10/rptOOS_20201010.delta', 'processed_full_path': '/Users/kom/code/ananta/ananta/src/ananta/sandbox/build/result/Bronze/ESS/rptOOS/VN/Processed', 'contract': '/Users/kom/code/ananta/ananta/src/ananta/sandbox/data/DataContract/Bronze/Processed/VN/ESS_rptOOS.json', 'file_name': '/rptOOS_20201010.delta'}, 'database': {'schema': 'ess', 'table': 'ess.rptoos', 'source_table': 'rptoos_src', 'partition_by': 'yyyy,mm,dd'}, 'file': {'ext': 'parquet'}, 'schema': {'struct': StructType(List(StructField("transactiondate",TimestampType,true),StructField("customercode",StringType,true),StructField("storetypecode",StringType,true),StructField("top",StringType,true),StructField("storecode",StringType,true),StructField("activeskucode",StringType,true),StructField("coretype",StringType,true),StructField("dpcode",StringType,true),StructField("stockonshelf",IntegerType,true),StructField("stocknorm",IntegerType,true),StructField("source",StringType,true),StructField("modeldeliverycode",IntegerType,true),StructField("modeldeliveryname",StringType,true),StructField("reasonlevel1",StringType,true),StructField("reasonlevel2",StringType,true),StructField("reasonlevel3",StringType,true),StructField("reasongroup",IntegerType,true),StructField("srreasoncode",StringType,true),StructField("srreasonname",StringType,true),StructField("reasoncode",StringType,true),StructField("reasondescription",StringType,true),StructField("note",StringType,true),StructField("status",StringType,true),StructField("csecode",StringType,true),StructField("csename",StringType,true),StructField("picrole",StringType,true),StructField("piccode",StringType,true),StructField("srcode",StringType,true),StructField("creatorcode",StringType,true),StructField("creatortime",StringType,true),StructField("lastrevisedbycode",StringType,true),StructField("lastrevisedbytime",StringType,true),StructField("deleted",StringType,true),StructField("createdby",TimestampType,true),StructField("createdtime",TimestampType,true),StructField("lastupdatedby",TimestampType,true),StructField("lastupdatedtime",TimestampType,true),StructField("dataversion",StringType,true),StructField("rdd",StringType,true),StructField("rowversion",TimestampType,true))), 'root': ['contract_uuid String', 'contract_name String', 'contract_description String', 'contract_layer String', 'contract_stage String', 'contract_data_source String', 'contract_object_name String', 'contract_fields String', 'contract_data_owner String', 'contract_process_owner String', 'contract_country String', 'contract_is_enable Boolean', 'contract_created_timestamp Timestamp', 'contract_updated_timestamp Timestamp', 'contract_cron String'], 'primary_keys': ['transactiondate', 'storecode', 'dpcode', 'reasoncode', 'csecode']}}
# --CORE: Found 0 custom udf
# /Users/kom/code/ananta/ananta/src/ananta/sandbox/build/result/Bronze/ESS/rptOOS/VN/Landed/YYYY=2020/MM=10/DD=10/rptOOS_20201010.delta/YYYY=2020/MM=10/DD=10/rptOOS_20201010.parquet
# 23/03/09 09:43:54 WARN ANANTA: Initialized Ananta
# 23/03/09 09:43:54 WARN ANANTA: DEBUG: NO file_path : looking new /Users/kom/code/ananta/ananta/src/ananta/sandbox/build/result/Bronze/ESS/rptOOS/VN/Landed/YYYY=2020/MM=10/DD=10/rptOOS_20201010.delta/YYYY=2020/MM=10/DD=10/rptOOS_20201010.parquet
# 23/03/09 09:43:54 WARN ANANTA: /Users/kom/code/ananta/ananta/src/ananta/sandbox/data/DataContract/Bronze/Processed/VN/ESS_rptOOS.json
# 23/03/09 09:43:54 WARN ANANTA: CONTRACT: BROKER: Looking at /Users/kom/code/ananta/ananta/src/ananta/sandbox/data/DataContract/Bronze/Processed/VN/ESS_rptOOS.json - Found True
# 23/03/09 09:43:54 WARN ANANTA: ASSIGNED: BronzeProcessedProcessor
# 23/03/09 09:43:54 WARN ANANTA: {'path': {'datalake_path': '/Users/kom/code/ananta/ananta/src/ananta/sandbox/build/result', 'object_path': '/Bronze/ESS/rptOOS/VN/Processed', 'datetime_path': '/YYYY=2020/MM=10/DD=10', 'full_path': '/Users/kom/code/ananta/ananta/src/ananta/sandbox/build/result/Bronze/ESS/rptOOS/VN/Processed/YYYY=2020/MM=10/DD=10/rptOOS_20201010.delta', 'processed_full_path': '/Users/kom/code/ananta/ananta/src/ananta/sandbox/build/result/Bronze/ESS/rptOOS/VN/Processed', 'contract': '/Users/kom/code/ananta/ananta/src/ananta/sandbox/data/DataContract/Bronze/Processed/VN/ESS_rptOOS.json', 'file_name': '/rptOOS_20201010.delta'}, 'database': {'schema': 'ess', 'table': 'ess.rptoos', 'source_table': 'rptoos_src', 'partition_by': 'yyyy,mm,dd'}, 'file': {'ext': 'parquet'}, 'schema': {'struct': StructType(List(StructField("transactiondate",TimestampType,true),StructField("customercode",StringType,true),StructField("storetypecode",StringType,true),StructField("top",StringType,true),StructField("storecode",StringType,true),StructField("activeskucode",StringType,true),StructField("coretype",StringType,true),StructField("dpcode",StringType,true),StructField("stockonshelf",IntegerType,true),StructField("stocknorm",IntegerType,true),StructField("source",StringType,true),StructField("modeldeliverycode",IntegerType,true),StructField("modeldeliveryname",StringType,true),StructField("reasonlevel1",StringType,true),StructField("reasonlevel2",StringType,true),StructField("reasonlevel3",StringType,true),StructField("reasongroup",IntegerType,true),StructField("srreasoncode",StringType,true),StructField("srreasonname",StringType,true),StructField("reasoncode",StringType,true),StructField("reasondescription",StringType,true),StructField("note",StringType,true),StructField("status",StringType,true),StructField("csecode",StringType,true),StructField("csename",StringType,true),StructField("picrole",StringType,true),StructField("piccode",StringType,true),StructField("srcode",StringType,true),StructField("creatorcode",StringType,true),StructField("creatortime",StringType,true),StructField("lastrevisedbycode",StringType,true),StructField("lastrevisedbytime",StringType,true),StructField("deleted",StringType,true),StructField("createdby",TimestampType,true),StructField("createdtime",TimestampType,true),StructField("lastupdatedby",TimestampType,true),StructField("lastupdatedtime",TimestampType,true),StructField("dataversion",StringType,true),StructField("rdd",StringType,true),StructField("rowversion",TimestampType,true))), 'root': ['contract_uuid String', 'contract_name String', 'contract_description String', 'contract_layer String', 'contract_stage String', 'contract_data_source String', 'contract_object_name String', 'contract_fields String', 'contract_data_owner String', 'contract_process_owner String', 'contract_country String', 'contract_is_enable Boolean', 'contract_created_timestamp Timestamp', 'contract_updated_timestamp Timestamp', 'contract_cron String'], 'primary_keys': ['transactiondate', 'storecode', 'dpcode', 'reasoncode', 'csecode']}}
# 23/03/09 09:43:54 WARN ANANTA: CORE: Found 0 custom udf
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# Cell In[5], line 84
#      55 app = Ananta(
#      56     country=COUNTRY,
#      57     layer=LAYER,
#    (...)
#      65     landing_date=LANDING_DATE,
#      66 )
#      69 # def custom_function():
#      70 #     return F.concat(
#      71 #         "seller_id",
#    (...)
#      82 # app.add_custom_udf("colB", "custom_function2", "PRE_TRANSFORM", None)
#      83 # app.add_custom_udf("colC", "custom_function3", "POST_LOAD", None)
# ---> 84 app.run()
#      85 # app.custom_udf(function_name, "extract/transform/load")  # pre/post
#      86 # print_var(app.processor.dict())
#      87 print(f"-----Result {app.input_df.count()}")  # type: ignore
#
# File ~/code/ananta/ananta/src/ananta/core.py:344, in Ananta.run(self)
#     342 """Run itself"""
#     343 self.check_contract()
# --> 344 self.execute()
#     345 # self.log_runtime_report()
#     346 self.generate_data_quality_report()
#
# File ~/code/ananta/ananta/src/ananta/core.py:319, in Ananta.execute(self)
#     317 self.logger.log(f"CORE: Found {self.custom_steps_count} custom udf")  # type: ignore
#     318 # Extract
# --> 319 self.input_df = self.processor.extract()
#     320 self.input_df = self.execute_custom_udf("POST_EXTRACT")
#     321 self.report["raw"] = self.input_df.count()
#
# File ~/code/ananta/ananta/src/ananta/DataOnboarder/Processor/IBaseProcessor.py:48, in BronzeProcessedProcessor.extract(self)
#      46 def extract(self) -> DataFrame:
#      47     reader = self.file_reader(**self.__dict__)
# ---> 48     self.input_df = reader.read()
#      49     return self.input_df
#
# File ~/code/ananta/ananta/src/ananta/DataOnboarder/Processor/IFileReader.py:131, in ParquetFileReader.read(self, **options)
#     121 """Read Excel file with builder
#     122
#     123 Files are read with pandas then convert to pyspark dataframe
#    (...)
#     128 :rtype: dataframe
#     129 """
#     130 print(self.file_path)
# --> 131 return self.spark.read.format("parquet").load(self.file_path)
#
# File ~/miniconda3/envs/home-adb/lib/python3.8/site-packages/pyspark/sql/readwriter.py:158, in DataFrameReader.load(self, path, format, schema, **options)
#     156 self.options(**options)
#     157 if isinstance(path, str):
# --> 158     return self._df(self._jreader.load(path))
#     159 elif path is not None:
#     160     if type(path) != list:
#
# File ~/miniconda3/envs/home-adb/lib/python3.8/site-packages/py4j/java_gateway.py:1321, in JavaMember.__call__(self, *args)
#    1315 command = proto.CALL_COMMAND_NAME +\
#    1316     self.command_header +\
#    1317     args_command +\
#    1318     proto.END_COMMAND_PART
#    1320 answer = self.gateway_client.send_command(command)
# -> 1321 return_value = get_return_value(
#    1322     answer, self.gateway_client, self.target_id, self.name)
#    1324 for temp_arg in temp_args:
#    1325     temp_arg._detach()
#
# File ~/miniconda3/envs/home-adb/lib/python3.8/site-packages/pyspark/sql/utils.py:117, in capture_sql_exception.<locals>.deco(*a, **kw)
#     113 converted = convert_exception(e.java_exception)
#     114 if not isinstance(converted, UnknownException):
#     115     # Hide where the exception came from that shows a non-Pythonic
#     116     # JVM exception message.
# --> 117     raise converted from None
#     118 else:
#     119     raise
#
# AnalysisException: Path does not exist: file:/Users/kom/code/ananta/ananta/src/ananta/sandbox/build/result/Bronze/ESS/rptOOS/VN/Landed/YYYY=2020/MM=10/DD=10/rptOOS_20201010.delta/YYYY=2020/MM=10/DD=10/rptOOS_20201010.parquet

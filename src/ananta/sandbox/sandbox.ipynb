# %%
from pyspark.sql import SparkSession

spark = (
    SparkSession.builder.appName("lappy")
    .master("spark://192.168.31.78:7077")
    .getOrCreate()
)
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# c:\Users\PtPashantTripathi\code\ananta\sandbox.ipynb Cell 1 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/PtPashantTripathi/code/ananta/sandbox.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> from pyspark.sql import SparkSession
# ----> <a href='vscode-notebook-cell:/c%3A/Users/PtPashantTripathi/code/ananta/sandbox.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> spark = SparkSession.builder.appName('lappy').master('spark://192.168.31.78:7077').getOrCreate()
#
# File c:\Users\PtPashantTripathi\anaconda3\envs\local-adb\lib\site-packages\pyspark\sql\session.py:228, in SparkSession.Builder.getOrCreate(self)
#     226         sparkConf.set(key, value)
#     227     # This SparkContext may be an existing one.
# --> 228     sc = SparkContext.getOrCreate(sparkConf)
# ...
